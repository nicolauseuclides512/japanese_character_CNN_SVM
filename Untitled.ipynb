# %%
import sys
# !{sys.executable} -m pip install -U pip --user
# !{sys.executable} -m pip install -U codeium-jupyter --user
# !jupyter nbextension install --py codeium --user
# !jupyter nbextension enable --py codeium --user
# !jupyter serverextension enable --py codeium --user
# Out:
# Requirement already satisfied: pip in d:\anaconda\lib\site-packages (22.3.1)
# Collecting pip
#   Downloading pip-23.1.2-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: pip
# Successfully installed pip-23.1.2
#   WARNING: The scripts pip.exe, pip3.10.exe and pip3.exe are installed in 'C:\Users\nicoe\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting codeium-jupyter
#   Downloading codeium_jupyter-1.1.21-py3-none-any.whl (20 kB)
# Collecting aiohttp (from codeium-jupyter)
#   Downloading aiohttp-3.8.4-cp310-cp310-win_amd64.whl (319 kB)
#                                               0.0/319.8 kB ? eta -:--:--
#      --------                                71.7/319.8 kB 2.0 MB/s eta 0:00:01
#      --------------------------             225.3/319.8 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 319.8/319.8 kB 2.5 MB/s eta 0:00:00
# Collecting crc32c (from codeium-jupyter)
#   Downloading crc32c-2.3.post0-cp310-cp310-win_amd64.whl (32 kB)
# Requirement already satisfied: jupyter in d:\anaconda\lib\site-packages (from codeium-jupyter) (1.0.0)
# Requirement already satisfied: jupyter_core in d:\anaconda\lib\site-packages (from codeium-jupyter) (5.2.0)
# Requirement already satisfied: nbconvert in d:\anaconda\lib\site-packages (from codeium-jupyter) (6.5.4)
# Requirement already satisfied: notebook>=4.2 in d:\anaconda\lib\site-packages (from codeium-jupyter) (6.5.2)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (6.1)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (23.2.0)
# Requirement already satisfied: argon2-cffi in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (21.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (5.7.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (7.3.4)
# Requirement already satisfied: ipython-genutils in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.2.0)
# Requirement already satisfied: nbformat in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (5.7.0)
# Requirement already satisfied: nest-asyncio>=1.5 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (1.5.6)
# Requirement already satisfied: ipykernel in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.17.1)
# Requirement already satisfied: prometheus-client in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in d:\anaconda\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.5.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\lib\site-packages (from jupyter_core->codeium-jupyter) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\lib\site-packages (from jupyter_core->codeium-jupyter) (305.1)
# Requirement already satisfied: lxml in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (4.11.1)
# Requirement already satisfied: bleach in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (0.5.13)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (22.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (2.11.2)
# Requirement already satisfied: tinycss2 in d:\anaconda\lib\site-packages (from nbconvert->codeium-jupyter) (1.2.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp->codeium-jupyter) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in d:\anaconda\lib\site-packages (from aiohttp->codeium-jupyter) (2.0.4)
# Collecting multidict<7.0,>=4.5 (from aiohttp->codeium-jupyter)
#   Downloading multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->codeium-jupyter)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->codeium-jupyter)
#   Downloading yarl-1.9.2-cp310-cp310-win_amd64.whl (61 kB)
#                                               0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->codeium-jupyter)
#   Downloading frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->codeium-jupyter)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: qtconsole in d:\anaconda\lib\site-packages (from jupyter->codeium-jupyter) (5.4.0)
# Requirement already satisfied: jupyter-console in d:\anaconda\lib\site-packages (from jupyter->codeium-jupyter) (6.6.2)
# Requirement already satisfied: ipywidgets in d:\anaconda\lib\site-packages (from jupyter->codeium-jupyter) (7.6.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->codeium-jupyter) (2.8.2)
# Requirement already satisfied: jupyter-server>=1.8 in d:\anaconda\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in d:\anaconda\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.2.2)
# Requirement already satisfied: fastjsonschema in d:\anaconda\lib\site-packages (from nbformat->notebook>=4.2->codeium-jupyter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\lib\site-packages (from nbformat->notebook>=4.2->codeium-jupyter) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.2->codeium-jupyter) (2.0.10)
# Requirement already satisfied: idna>=2.0 in d:\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->codeium-jupyter) (3.4)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.2->codeium-jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4->nbconvert->codeium-jupyter) (2.3.2.post1)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda\lib\site-packages (from bleach->nbconvert->codeium-jupyter) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from bleach->nbconvert->codeium-jupyter) (0.5.1)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in d:\anaconda\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (8.10.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (0.1.6)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda\lib\site-packages (from ipywidgets->jupyter->codeium-jupyter) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda\lib\site-packages (from ipywidgets->jupyter->codeium-jupyter) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in d:\anaconda\lib\site-packages (from jupyter-console->jupyter->codeium-jupyter) (3.0.36)
# Requirement already satisfied: qtpy>=2.0.1 in d:\anaconda\lib\site-packages (from qtconsole->jupyter->codeium-jupyter) (2.2.0)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.18.1)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.7.5)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.2.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.4.6)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->codeium-jupyter) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (3.5.0)
# Requirement already satisfied: websocket-client in d:\anaconda\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.58.0)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->codeium-jupyter) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->codeium-jupyter) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (1.2.0)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->codeium-jupyter) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.8.3)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.2.2)
# Installing collected packages: crc32c, multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, codeium-jupyter
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 codeium-jupyter-1.1.21 crc32c-2.3.post0 frozenlist-1.3.3 multidict-6.0.4 yarl-1.9.2
# Installing C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static -> codeium
# Making directory: C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\codeium.yaml -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\codeium.yaml
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\codeium_square_error.svg -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_error.svg
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\codeium_square_inactive.svg -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_inactive.svg
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\codeium_square_logo.svg -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_logo.svg
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\codeium_square_processing.svg -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_processing.svg
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\codeium_square_warning.svg -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_warning.svg
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\main.css -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\main.css
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\main.js -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\main.js
# Copying: C:\Users\nicoe\AppData\Roaming\Python\Python310\site-packages\codeium\static\README.rst -> C:\Users\nicoe\AppData\Roaming\jupyter\nbextensions\codeium\README.rst
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable codeium --user --py
#
# Enabling notebook extension codeium/main...
#       - Validating: ok
# Enabling: codeium
# - Writing config: C:\Users\nicoe\.jupyter
#     - Validating...
#       codeium  ok

# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U codeium-jupyter
# !jupyter nbextension install --py codeium --user
# !jupyter nbextension enable --py codeium --user
# !jupyter serverextension enable --py codeium --user
